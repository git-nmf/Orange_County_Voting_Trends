# %% [markdown]
# ## 28_combine_census_data_extended
# ## This notebook handles adding extended census-tract data to srprec, then adding vote data

# %%
# imports
import pandas as pd
import numpy as np
import requests
import pickle as pkl
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Converter file

# %%
#bring in converter file, created in 25_srprec_tract_converter page
convert18 = pd.read_pickle('./data/df_convert18.pkl')

# %%
convert18.head(3)
# Out:
#    subindex  srprec_orig   tract  pctsrprec_tract
# 0         0         7701  110304       100.000000
# 1         0        75702   75809        97.095134
# 2         1        75702   75814         2.904866

# %%
convert18.shape
# Out:
# (2011, 4)

# %%
convert18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2011 entries, 0 to 2010
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   subindex         2011 non-null   int64
#  1   srprec_orig      2011 non-null   int64
#  2   tract            2011 non-null   int64
#  3   pctsrprec_tract  2011 non-null   float64
# dtypes: float64(1), int64(3)
# memory usage: 63.0 KB

# %% [markdown]
# ### Merge the full dataframes
# #### Steps:
# 1. Attach census data on 'tract', apply weights by 'tract', aggregate to 'srprec'.
# 2. Attach vote data on 'srprec'

# %% [markdown]
# #### Step 1:  Attach census data on 'tract', apply weights by 'tract', aggregate to 'srprec'.

# %% [markdown]
# #### Census data set

# %%
census18_DP03 = pd.read_pickle('./census_data/DP03_extended.pkl')
census18_DP03.shape
# Out:
# (583, 18)

# %%
census18_DP03.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 583 entries, 1 to 583
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   GEO_ID                583 non-null    object
#  1   tract                 583 non-null    int64
#  2   employed              583 non-null    int64
#  3   unemployed            583 non-null    int64
#  4   empl_military         583 non-null    int64
#  5   not_inlaborforce      583 non-null    int64
#  6   working_women         583 non-null    int64
#  7   parents_work_under6   583 non-null    int64
#  8   parents_work_0617     583 non-null    int64
#  9   occ_mgmt_sci_art      583 non-null    int64
#  10  occ_service_sector    583 non-null    int64
#  11  occ_sales_gen_office  583 non-null    int64
#  12  occ_constr_maintc     583 non-null    int64
#  13  occ_manuf_transpo     583 non-null    int64
#  14  hh_med_income         583 non-null    int64
#  15  hlthins_priv          583 non-null    int64
#  16  hlthins_public        583 non-null    int64
#  17  hlthins_none          583 non-null    int64
# dtypes: int64(17), object(1)
# memory usage: 86.5+ KB

# %%
census18_DP03.drop(['GEO_ID'], axis=1, inplace=True)

# %%
census18_DP03.head(3)
# Out:
# 0  tract  employed  unemployed  empl_military  not_inlaborforce  \
# 1  62644      3811         156              0              2800
# 2  62640      2320         116             10               616
# 3  63008       412          19              0               402
#
# 0  working_women  parents_work_under6  parents_work_0617  occ_mgmt_sci_art  \
# 1           1652                  133                862              2547
# 2           1234                  122                447              1202
# 3            239                    4                 43               255
#
# 0  occ_service_sector  occ_sales_gen_office  occ_constr_maintc  \
# 1                 262                   819                 91
# 2                 287                   563                 63
# 3                  22                   104                  0
#
# 0  occ_manuf_transpo  hh_med_income  hlthins_priv  hlthins_public  \
# 1                 92         146953          7854            1504
# 2                205          84632          2687             889
# 3                 31         100396           668             396
#
# 0  hlthins_none
# 1           245
# 2           263
# 3             0

# %%
census18_DP03.shape
# Out:
# (583, 17)

# %% [markdown]
# #### Merge census data into convert18 df on 'tract' to create combo df

# %%
# pd.merge(left=c, right=b, how='outer', left_on=['tract'], right_on=['tract'], indicator=True, suffixes=('_c', '_b'))
combo = pd.merge(left=convert18, right=census18_DP03, how='outer', left_on=['tract'], right_on=['tract'], indicator=True)

# %%
combo.head(10)
# Out:
#    subindex  srprec_orig   tract  pctsrprec_tract  employed  unemployed  \
# 0       0.0       7701.0  110304       100.000000      2614         187
# 1       0.0       7140.0  110304       100.000000      2614         187
# 2       0.0       7138.0  110304       100.000000      2614         187
# 3       0.0      11075.0  110304       100.000000      2614         187
# 4       2.0      11043.0  110304        25.630594      2614         187
# 5       0.0      75702.0   75809        97.095134      1188         107
# 6       0.0      75116.0   75809        70.290635      1188         107
# 7       0.0      75110.0   75809        16.946309      1188         107
# 8       0.0      63710.0   75809         4.524089      1188         107
# 9       1.0      75702.0   75814         2.904866      1567         114
#
#    empl_military  not_inlaborforce  working_women  parents_work_under6  ...  \
# 0              0              1442           1305                  244  ...
# 1              0              1442           1305                  244  ...
# 2              0              1442           1305                  244  ...
# 3              0              1442           1305                  244  ...
# 4              0              1442           1305                  244  ...
# 5              0              1191            548                   10  ...
# 6              0              1191            548                   10  ...
# 7              0              1191            548                   10  ...
# 8              0              1191            548                   10  ...
# 9              0               716            790                  111  ...
#
#    occ_mgmt_sci_art  occ_service_sector  occ_sales_gen_office  \
# 0               875                 621                   697
# 1               875                 621                   697
# 2               875                 621                   697
# 3               875                 621                   697
# 4               875                 621                   697
# 5               725                 133                   238
# 6               725                 133                   238
# 7               725                 133                   238
# 8               725                 133                   238
# 9               890                 199                   388
#
#    occ_constr_maintc  occ_manuf_transpo  hh_med_income  hlthins_priv  \
# 0                195                226         105746          3707
# 1                195                226         105746          3707
# 2                195                226         105746          3707
# 3                195                226         105746          3707
# 4                195                226         105746          3707
# 5                 71                 21         165278          2281
# 6                 71                 21         165278          2281
# 7                 71                 21         165278          2281
# 8                 71                 21         165278          2281
# 9                  0                 90         130438          2500
#
#    hlthins_public  hlthins_none  _merge
# 0            1497           181    both
# 1            1497           181    both
# 2            1497           181    both
# 3            1497           181    both
# 4            1497           181    both
# 5            1012            71    both
# 6            1012            71    both
# 7            1012            71    both
# 8            1012            71    both
# 9             566            68    both
#
# [10 rows x 21 columns]

# %%
combo.shape
# Out:
# (2012, 21)

# %%
combo['_merge'].value_counts()
# Out:
# both          2011
# right_only       1
# left_only        0
# Name: _merge, dtype: int64

# %%
combo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2012 entries, 0 to 2011
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   subindex              2011 non-null   float64
#  1   srprec_orig           2011 non-null   float64
#  2   tract                 2012 non-null   int64
#  3   pctsrprec_tract       2011 non-null   float64
#  4   employed              2012 non-null   int64
#  5   unemployed            2012 non-null   int64
#  6   empl_military         2012 non-null   int64
#  7   not_inlaborforce      2012 non-null   int64
#  8   working_women         2012 non-null   int64
#  9   parents_work_under6   2012 non-null   int64
#  10  parents_work_0617     2012 non-null   int64
#  11  occ_mgmt_sci_art      2012 non-null   int64
#  12  occ_service_sector    2012 non-null   int64
#  13  occ_sales_gen_office  2012 non-null   int64
#  14  occ_constr_maintc     2012 non-null   int64
#  15  occ_manuf_transpo     2012 non-null   int64
#  16  hh_med_income         2012 non-null   int64
#  17  hlthins_priv          2012 non-null   int64
#  18  hlthins_public        2012 non-null   int64
#  19  hlthins_none          2012 non-null   int64
#  20  _merge                2012 non-null   category
# dtypes: category(1), float64(3), int64(17)
# memory usage: 332.2 KB

# %% [markdown]
# #### Inspect resulting dataframe:  'srprec' with multiple tracts, nulls

# %%
#stackoverflow:  https://stackoverflow.com/questions/14247586/how-to-select-rows-with-one-or-more-nulls-from-a-pandas-dataframe-without-listin
combo[pd.isnull(combo).any(axis=1)]
# Out:
#       subindex  srprec_orig   tract  pctsrprec_tract  employed  unemployed  \
# 2011       NaN          NaN  990100              NaN         0           0
#
#       empl_military  not_inlaborforce  working_women  parents_work_under6  \
# 2011              0                 0              0                    0
#
#       ...  occ_mgmt_sci_art  occ_service_sector  occ_sales_gen_office  \
# 2011  ...                 0                   0                     0
#
#       occ_constr_maintc  occ_manuf_transpo  hh_med_income  hlthins_priv  \
# 2011                  0                  0     -666666666             0
#
#       hlthins_public  hlthins_none      _merge
# 2011               0             0  right_only
#
# [1 rows x 21 columns]

# %%
combo.loc[combo['srprec_orig'] == 14082]
# Out:
#       subindex  srprec_orig   tract  pctsrprec_tract  employed  unemployed  \
# 1567       0.0      14082.0   88101         0.127389      1123          55
# 1878       1.0      14082.0  110003        99.872611      1496          47
#
#       empl_military  not_inlaborforce  working_women  parents_work_under6  \
# 1567              7               552            425                  138
# 1878             14               930            763                  202
#
#       ...  occ_mgmt_sci_art  occ_service_sector  occ_sales_gen_office  \
# 1567  ...               356                 275                   306
# 1878  ...               731                 116                   372
#
#       occ_constr_maintc  occ_manuf_transpo  hh_med_income  hlthins_priv  \
# 1567                 98                 88          74665          1368
# 1878                150                127          86176          2521
#
#       hlthins_public  hlthins_none  _merge
# 1567             982           186    both
# 1878             954            94    both
#
# [2 rows x 21 columns]

# %%
combo.loc[combo['_merge'] == 'right_only']
# Out:
#       subindex  srprec_orig   tract  pctsrprec_tract  employed  unemployed  \
# 2011       NaN          NaN  990100              NaN         0           0
#
#       empl_military  not_inlaborforce  working_women  parents_work_under6  \
# 2011              0                 0              0                    0
#
#       ...  occ_mgmt_sci_art  occ_service_sector  occ_sales_gen_office  \
# 2011  ...                 0                   0                     0
#
#       occ_constr_maintc  occ_manuf_transpo  hh_med_income  hlthins_priv  \
# 2011                  0                  0     -666666666             0
#
#       hlthins_public  hlthins_none      _merge
# 2011               0             0  right_only
#
# [1 rows x 21 columns]

# %%
combo.drop(index=2011, inplace=True)

# %%
combo['pctsrprec_tract'] = round(combo['pctsrprec_tract'], 2)

# %%
combo.head(10)
# Out:
#    subindex  srprec_orig   tract  pctsrprec_tract  employed  unemployed  \
# 0       0.0       7701.0  110304           100.00      2614         187
# 1       0.0       7140.0  110304           100.00      2614         187
# 2       0.0       7138.0  110304           100.00      2614         187
# 3       0.0      11075.0  110304           100.00      2614         187
# 4       2.0      11043.0  110304            25.63      2614         187
# 5       0.0      75702.0   75809            97.10      1188         107
# 6       0.0      75116.0   75809            70.29      1188         107
# 7       0.0      75110.0   75809            16.95      1188         107
# 8       0.0      63710.0   75809             4.52      1188         107
# 9       1.0      75702.0   75814             2.90      1567         114
#
#    empl_military  not_inlaborforce  working_women  parents_work_under6  ...  \
# 0              0              1442           1305                  244  ...
# 1              0              1442           1305                  244  ...
# 2              0              1442           1305                  244  ...
# 3              0              1442           1305                  244  ...
# 4              0              1442           1305                  244  ...
# 5              0              1191            548                   10  ...
# 6              0              1191            548                   10  ...
# 7              0              1191            548                   10  ...
# 8              0              1191            548                   10  ...
# 9              0               716            790                  111  ...
#
#    occ_mgmt_sci_art  occ_service_sector  occ_sales_gen_office  \
# 0               875                 621                   697
# 1               875                 621                   697
# 2               875                 621                   697
# 3               875                 621                   697
# 4               875                 621                   697
# 5               725                 133                   238
# 6               725                 133                   238
# 7               725                 133                   238
# 8               725                 133                   238
# 9               890                 199                   388
#
#    occ_constr_maintc  occ_manuf_transpo  hh_med_income  hlthins_priv  \
# 0                195                226         105746          3707
# 1                195                226         105746          3707
# 2                195                226         105746          3707
# 3                195                226         105746          3707
# 4                195                226         105746          3707
# 5                 71                 21         165278          2281
# 6                 71                 21         165278          2281
# 7                 71                 21         165278          2281
# 8                 71                 21         165278          2281
# 9                  0                 90         130438          2500
#
#    hlthins_public  hlthins_none  _merge
# 0            1497           181    both
# 1            1497           181    both
# 2            1497           181    both
# 3            1497           181    both
# 4            1497           181    both
# 5            1012            71    both
# 6            1012            71    both
# 7            1012            71    both
# 8            1012            71    both
# 9             566            68    both
#
# [10 rows x 21 columns]

# %% [markdown]
# #### Calculate weighted values for each tract

# %% [markdown]
# **NOTE** Opportunity to perform this calculation as a for-loop or function, but for time-constraints and precision, I calculated by hand

# %%
combo['employed_wgt'] = round((combo['pctsrprec_tract']/100 * combo['employed']), 0)

# %%
combo['unemployed_wgt'] = round((combo['pctsrprec_tract']/100 * combo['unemployed']), 0)
combo['empl_military_wgt'] = round((combo['pctsrprec_tract']/100 * combo['empl_military']), 0)
combo['not_inlaborforce_wgt'] = round((combo['pctsrprec_tract']/100 * combo['not_inlaborforce']), 0)

# %%
combo['working_women_wgt'] = round((combo['pctsrprec_tract']/100 * combo['working_women']), 0)
combo['parents_work_under6_wgt'] = round((combo['pctsrprec_tract']/100 * combo['parents_work_under6']), 0)
combo['parents_work_0617_wgt'] = round((combo['pctsrprec_tract']/100 * combo['parents_work_0617']), 0)

# %%
combo['occ_mgmt_sci_art_wgt'] = round((combo['pctsrprec_tract']/100 * combo['occ_mgmt_sci_art']), 0)
combo['occ_service_sector_wgt'] = round((combo['pctsrprec_tract']/100 * combo['occ_service_sector']), 0)
combo['occ_sales_gen_office_wgt'] = round((combo['pctsrprec_tract']/100 * combo['occ_sales_gen_office']), 0)

# %%
combo['occ_constr_maintc_wgt'] = round((combo['pctsrprec_tract']/100 * combo['occ_constr_maintc']), 0)
combo['occ_manuf_transpo_wgt'] = round((combo['pctsrprec_tract']/100 * combo['occ_manuf_transpo']), 0)
combo['hh_med_income_wgt'] = round((combo['pctsrprec_tract']/100 * combo['hh_med_income']), 0)

# %%
combo['hlthins_priv_wgt'] = round((combo['pctsrprec_tract']/100 * combo['hlthins_priv']), 0)
combo['hlthins_public_wgt'] = round((combo['pctsrprec_tract']/100 * combo['hlthins_public']), 0)
combo['hlthins_none_wgt'] = round((combo['pctsrprec_tract']/100 * combo['hlthins_none']), 0)

# %%
combo.head(10).T
# Out:
#                                0       1       2       3       4       5  \
# subindex                       0       0       0       0       2       0
# srprec_orig                 7701    7140    7138   11075   11043   75702
# tract                     110304  110304  110304  110304  110304   75809
# pctsrprec_tract              100     100     100     100   25.63    97.1
# employed                    2614    2614    2614    2614    2614    1188
# unemployed                   187     187     187     187     187     107
# empl_military                  0       0       0       0       0       0
# not_inlaborforce            1442    1442    1442    1442    1442    1191
# working_women               1305    1305    1305    1305    1305     548
# parents_work_under6          244     244     244     244     244      10
# parents_work_0617            548     548     548     548     548     232
# occ_mgmt_sci_art             875     875     875     875     875     725
# occ_service_sector           621     621     621     621     621     133
# occ_sales_gen_office         697     697     697     697     697     238
# occ_constr_maintc            195     195     195     195     195      71
# occ_manuf_transpo            226     226     226     226     226      21
# hh_med_income             105746  105746  105746  105746  105746  165278
# hlthins_priv                3707    3707    3707    3707    3707    2281
# hlthins_public              1497    1497    1497    1497    1497    1012
# hlthins_none                 181     181     181     181     181      71
# _merge                      both    both    both    both    both    both
# employed_wgt                2614    2614    2614    2614     670    1154
# unemployed_wgt               187     187     187     187      48     104
# empl_military_wgt              0       0       0       0       0       0
# not_inlaborforce_wgt        1442    1442    1442    1442     370    1156
# working_women_wgt           1305    1305    1305    1305     334     532
# parents_work_under6_wgt      244     244     244     244      63      10
# parents_work_0617_wgt        548     548     548     548     140     225
# occ_mgmt_sci_art_wgt         875     875     875     875     224     704
# occ_service_sector_wgt       621     621     621     621     159     129
# occ_sales_gen_office_wgt     697     697     697     697     179     231
# occ_constr_maintc_wgt        195     195     195     195      50      69
# occ_manuf_transpo_wgt        226     226     226     226      58      20
# hh_med_income_wgt         105746  105746  105746  105746   27103  160485
# hlthins_priv_wgt            3707    3707    3707    3707     950    2215
# hlthins_public_wgt          1497    1497    1497    1497     384     983
# hlthins_none_wgt             181     181     181     181      46      69
#
#                                6       7       8       9
# subindex                       0       0       0       1
# srprec_orig                75116   75110   63710   75702
# tract                      75809   75809   75809   75814
# pctsrprec_tract            70.29   16.95    4.52     2.9
# employed                    1188    1188    1188    1567
# unemployed                   107     107     107     114
# empl_military                  0       0       0       0
# not_inlaborforce            1191    1191    1191     716
# working_women                548     548     548     790
# parents_work_under6           10      10      10     111
# parents_work_0617            232     232     232     206
# occ_mgmt_sci_art             725     725     725     890
# occ_service_sector           133     133     133     199
# occ_sales_gen_office         238     238     238     388
# occ_constr_maintc             71      71      71       0
# occ_manuf_transpo             21      21      21      90
# hh_med_income             165278  165278  165278  130438
# hlthins_priv                2281    2281    2281    2500
# hlthins_public              1012    1012    1012     566
# hlthins_none                  71      71      71      68
# _merge                      both    both    both    both
# employed_wgt                 835     201      54      45
# unemployed_wgt                75      18       5       3
# empl_military_wgt              0       0       0       0
# not_inlaborforce_wgt         837     202      54      21
# working_women_wgt            385      93      25      23
# parents_work_under6_wgt        7       2       0       3
# parents_work_0617_wgt        163      39      10       6
# occ_mgmt_sci_art_wgt         510     123      33      26
# occ_service_sector_wgt        93      23       6       6
# occ_sales_gen_office_wgt     167      40      11      11
# occ_constr_maintc_wgt         50      12       3       0
# occ_manuf_transpo_wgt         15       4       1       3
# hh_med_income_wgt         116174   28015    7471    3783
# hlthins_priv_wgt            1603     387     103      72
# hlthins_public_wgt           711     172      46      16
# hlthins_none_wgt              50      12       3       2

# %% [markdown]
# #### spot-checks

# %%
combo.loc[combo['srprec_orig'] == 75116]
# Out:
#     subindex  srprec_orig  tract  pctsrprec_tract  employed  unemployed  \
# 6        0.0      75116.0  75809            70.29      1188         107
# 10       4.0      75116.0  75814             0.43      1567         114
# 18       1.0      75116.0  75810            21.10      1226          34
# 23       2.0      75116.0  75811             6.24      1576          89
# 26       3.0      75116.0  75813             1.94      2490         152
#
#     empl_military  not_inlaborforce  working_women  parents_work_under6  ...  \
# 6               0              1191            548                   10  ...
# 10              0               716            790                  111  ...
# 18              0              1361            505                   48  ...
# 23              0               906            571                   76  ...
# 26              0              1592           1188                  132  ...
#
#     parents_work_0617_wgt  occ_mgmt_sci_art_wgt  occ_service_sector_wgt  \
# 6                   163.0                 510.0                    93.0
# 10                    1.0                   4.0                     1.0
# 18                   55.0                 130.0                    19.0
# 23                   16.0                  32.0                    22.0
# 26                    5.0                  22.0                     8.0
#
#     occ_sales_gen_office_wgt  occ_constr_maintc_wgt  occ_manuf_transpo_wgt  \
# 6                      167.0                   50.0                   15.0
# 10                       2.0                    0.0                    0.0
# 18                      82.0                   18.0                   10.0
# 23                      18.0                   13.0                   13.0
# 26                      13.0                    2.0                    3.0
#
#     hh_med_income_wgt  hlthins_priv_wgt  hlthins_public_wgt  hlthins_none_wgt
# 6            116174.0            1603.0               711.0              50.0
# 10              561.0              11.0                 2.0               0.0
# 18            25782.0             510.0               210.0              26.0
# 23             4455.0             116.0                65.0              40.0
# 26             2360.0              78.0                28.0               3.0
#
# [5 rows x 37 columns]

# %% [markdown]
# #### Aggregate results to 'srprec'

# %%
srprec_agg = combo.groupby('srprec_orig').sum()
srprec_agg
# Out:
#              subindex   tract  pctsrprec_tract  employed  unemployed  \
# srprec_orig
# 2001.0            3.0  184605            100.0      7357         444
# 2002.0            0.0   11720            100.0      2881         217
# 2008.0            0.0   86702            100.0      3948         278
# 2009.0            3.0  284005            100.0      9352         464
# 2011.0            0.0   21905            100.0      2991          74
# ...               ...     ...              ...       ...         ...
# 75116.0          10.0  379057            100.0      8047         496
# 75117.0           0.0   75810            100.0      1226          34
# 75122.0           0.0   75810            100.0      1226          34
# 75701.0           0.0   75810            100.0      1226          34
# 75702.0           1.0  151623            100.0      2755         221
#
#              empl_military  not_inlaborforce  working_women  \
# srprec_orig
# 2001.0                   0              4031           3316
# 2002.0                   9              1525           1030
# 2008.0                   0              1438           1656
# 2009.0                   0              7497           4413
# 2011.0                   0              1401           1486
# ...                    ...               ...            ...
# 75116.0                  0              5766           3602
# 75117.0                  0              1361            505
# 75122.0                  0              1361            505
# 75701.0                  0              1361            505
# 75702.0                  0              1907           1338
#
#              parents_work_under6  parents_work_0617  ...  \
# srprec_orig                                          ...
# 2001.0                       781               2146  ...
# 2002.0                       257               1082  ...
# 2008.0                       561                677  ...
# 2009.0                       830               2251  ...
# 2011.0                       334                492  ...
# ...                          ...                ...  ...
# 75116.0                      377               1221  ...
# 75117.0                       48                262  ...
# 75122.0                       48                262  ...
# 75701.0                       48                262  ...
# 75702.0                      121                438  ...
#
#              parents_work_0617_wgt  occ_mgmt_sci_art_wgt  \
# srprec_orig
# 2001.0                       783.0                 244.0
# 2002.0                      1082.0                 363.0
# 2008.0                       677.0                 675.0
# 2009.0                       717.0                 693.0
# 2011.0                       492.0                1364.0
# ...                            ...                   ...
# 75116.0                      240.0                 698.0
# 75117.0                      262.0                 615.0
# 75122.0                      262.0                 615.0
# 75701.0                      262.0                 615.0
# 75702.0                      231.0                 730.0
#
#              occ_service_sector_wgt  occ_sales_gen_office_wgt  \
# srprec_orig
# 2001.0                        637.0                     706.0
# 2002.0                        573.0                     383.0
# 2008.0                        796.0                    1064.0
# 2009.0                        701.0                     912.0
# 2011.0                        331.0                    1011.0
# ...                             ...                       ...
# 75116.0                       143.0                     282.0
# 75117.0                        91.0                     387.0
# 75122.0                        91.0                     387.0
# 75701.0                        91.0                     387.0
# 75702.0                       135.0                     242.0
#
#              occ_constr_maintc_wgt  occ_manuf_transpo_wgt  hh_med_income_wgt  \
# srprec_orig
# 2001.0                       405.0                  653.0            54480.0
# 2002.0                       569.0                  993.0            44136.0
# 2008.0                       368.0                 1045.0            66970.0
# 2009.0                       274.0                  465.0            54967.0
# 2011.0                       151.0                  134.0           119595.0
# ...                            ...                    ...                ...
# 75116.0                       83.0                   41.0           149332.0
# 75117.0                       87.0                   46.0           122188.0
# 75122.0                       87.0                   46.0           122188.0
# 75701.0                       87.0                   46.0           122188.0
# 75702.0                       69.0                   23.0           164268.0
#
#              hlthins_priv_wgt  hlthins_public_wgt  hlthins_none_wgt
# srprec_orig
# 2001.0                 2156.0              2846.0            1050.0
# 2002.0                 1885.0              3583.0            1700.0
# 2008.0                 3947.0              2926.0            1356.0
# 2009.0                 3794.0              2708.0             822.0
# 2011.0                 4400.0              1523.0             259.0
# ...                       ...                 ...               ...
# 75116.0                2318.0              1016.0             119.0
# 75117.0                2418.0               997.0             125.0
# 75122.0                2418.0               997.0             125.0
# 75701.0                2418.0               997.0             125.0
# 75702.0                2287.0               999.0              71.0
#
# [1334 rows x 35 columns]

# %%
srprec_agg.reset_index(inplace=True)

# %%
srprec_agg.head()
# Out:
#    srprec_orig  subindex   tract  pctsrprec_tract  employed  unemployed  \
# 0       2001.0       3.0  184605            100.0      7357         444
# 1       2002.0       0.0   11720            100.0      2881         217
# 2       2008.0       0.0   86702            100.0      3948         278
# 3       2009.0       3.0  284005            100.0      9352         464
# 4       2011.0       0.0   21905            100.0      2991          74
#
#    empl_military  not_inlaborforce  working_women  parents_work_under6  ...  \
# 0              0              4031           3316                  781  ...
# 1              9              1525           1030                  257  ...
# 2              0              1438           1656                  561  ...
# 3              0              7497           4413                  830  ...
# 4              0              1401           1486                  334  ...
#
#    parents_work_0617_wgt  occ_mgmt_sci_art_wgt  occ_service_sector_wgt  \
# 0                  783.0                 244.0                   637.0
# 1                 1082.0                 363.0                   573.0
# 2                  677.0                 675.0                   796.0
# 3                  717.0                 693.0                   701.0
# 4                  492.0                1364.0                   331.0
#
#    occ_sales_gen_office_wgt  occ_constr_maintc_wgt  occ_manuf_transpo_wgt  \
# 0                     706.0                  405.0                  653.0
# 1                     383.0                  569.0                  993.0
# 2                    1064.0                  368.0                 1045.0
# 3                     912.0                  274.0                  465.0
# 4                    1011.0                  151.0                  134.0
#
#    hh_med_income_wgt  hlthins_priv_wgt  hlthins_public_wgt  hlthins_none_wgt
# 0            54480.0            2156.0              2846.0            1050.0
# 1            44136.0            1885.0              3583.0            1700.0
# 2            66970.0            3947.0              2926.0            1356.0
# 3            54967.0            3794.0              2708.0             822.0
# 4           119595.0            4400.0              1523.0             259.0
#
# [5 rows x 36 columns]

# %% [markdown]
# #### Inspect

# %%
srprec_agg.loc[srprec_agg['srprec_orig'] == 75116]
# Out:
#       srprec_orig  subindex   tract  pctsrprec_tract  employed  unemployed  \
# 1329      75116.0      10.0  379057            100.0      8047         496
#
#       empl_military  not_inlaborforce  working_women  parents_work_under6  \
# 1329              0              5766           3602                  377
#
#       ...  parents_work_0617_wgt  occ_mgmt_sci_art_wgt  \
# 1329  ...                  240.0                 698.0
#
#       occ_service_sector_wgt  occ_sales_gen_office_wgt  occ_constr_maintc_wgt  \
# 1329                   143.0                     282.0                   83.0
#
#       occ_manuf_transpo_wgt  hh_med_income_wgt  hlthins_priv_wgt  \
# 1329                   41.0           149332.0            2318.0
#
#       hlthins_public_wgt  hlthins_none_wgt
# 1329              1016.0             119.0
#
# [1 rows x 36 columns]

# %% [markdown]
# #### **DROP TRACT DETAIL**

# %%
# cols that don't make sense in aggregate:
# subindex -- keep.  even if aggregated, it is a helpful indicator of an srprec which contains multiple tracts
# tract -- drop.  the aggregation adds tract numbers together, and it loses meaning
# original tract-level data -- drop.  no longer relevant, because it's been transformed to srprec-level

# %%
srprec_agg.columns.tolist()
# Out:
# ['srprec_orig',
#  'subindex',
#  'tract',
#  'pctsrprec_tract',
#  'employed',
#  'unemployed',
#  'empl_military',
#  'not_inlaborforce',
#  'working_women',
#  'parents_work_under6',
#  'parents_work_0617',
#  'occ_mgmt_sci_art',
#  'occ_service_sector',
#  'occ_sales_gen_office',
#  'occ_constr_maintc',
#  'occ_manuf_transpo',
#  'hh_med_income',
#  'hlthins_priv',
#  'hlthins_public',
#  'hlthins_none',
#  'employed_wgt',
#  'unemployed_wgt',
#  'empl_military_wgt',
#  'not_inlaborforce_wgt',
#  'working_women_wgt',
#  'parents_work_under6_wgt',
#  'parents_work_0617_wgt',
#  'occ_mgmt_sci_art_wgt',
#  'occ_service_sector_wgt',
#  'occ_sales_gen_office_wgt',
#  'occ_constr_maintc_wgt',
#  'occ_manuf_transpo_wgt',
#  'hh_med_income_wgt',
#  'hlthins_priv_wgt',
#  'hlthins_public_wgt',
#  'hlthins_none_wgt']

# %%
srprec_census = srprec_agg[['srprec_orig',
 'subindex',
 'pctsrprec_tract',
 'employed_wgt',
 'unemployed_wgt',
 'empl_military_wgt',
 'not_inlaborforce_wgt',
 'working_women_wgt',
 'parents_work_under6_wgt',
 'parents_work_0617_wgt',
 'occ_mgmt_sci_art_wgt',
 'occ_service_sector_wgt',
 'occ_sales_gen_office_wgt',
 'occ_constr_maintc_wgt',
 'occ_manuf_transpo_wgt',
 'hh_med_income_wgt',
 'hlthins_priv_wgt',
 'hlthins_public_wgt',
 'hlthins_none_wgt']]
srprec_census
# Out:
#       srprec_orig  subindex  pctsrprec_tract  employed_wgt  unemployed_wgt  \
# 0          2001.0       3.0            100.0        2647.0           161.0
# 1          2002.0       0.0            100.0        2881.0           217.0
# 2          2008.0       0.0            100.0        3948.0           278.0
# 3          2009.0       3.0            100.0        3045.0           147.0
# 4          2011.0       0.0            100.0        2991.0            74.0
# ...           ...       ...              ...           ...             ...
# 1329      75116.0      10.0            100.0        1247.0            91.0
# 1330      75117.0       0.0            100.0        1226.0            34.0
# 1331      75122.0       0.0            100.0        1226.0            34.0
# 1332      75701.0       0.0            100.0        1226.0            34.0
# 1333      75702.0       1.0            100.0        1199.0           107.0
#
#       empl_military_wgt  not_inlaborforce_wgt  working_women_wgt  \
# 0                   0.0                1372.0             1152.0
# 1                   9.0                1525.0             1030.0
# 2                   0.0                1438.0             1656.0
# 3                   0.0                2459.0             1447.0
# 4                   0.0                1401.0             1486.0
# ...                 ...                   ...                ...
# 1329                0.0                1215.0              554.0
# 1330                0.0                1361.0              505.0
# 1331                0.0                1361.0              505.0
# 1332                0.0                1361.0              505.0
# 1333                0.0                1177.0              555.0
#
#       parents_work_under6_wgt  parents_work_0617_wgt  occ_mgmt_sci_art_wgt  \
# 0                       268.0                  783.0                 244.0
# 1                       257.0                 1082.0                 363.0
# 2                       561.0                  677.0                 675.0
# 3                       273.0                  717.0                 693.0
# 4                       334.0                  492.0                1364.0
# ...                       ...                    ...                   ...
# 1329                     25.0                  240.0                 698.0
# 1330                     48.0                  262.0                 615.0
# 1331                     48.0                  262.0                 615.0
# 1332                     48.0                  262.0                 615.0
# 1333                     13.0                  231.0                 730.0
#
#       occ_service_sector_wgt  occ_sales_gen_office_wgt  occ_constr_maintc_wgt  \
# 0                      637.0                     706.0                  405.0
# 1                      573.0                     383.0                  569.0
# 2                      796.0                    1064.0                  368.0
# 3                      701.0                     912.0                  274.0
# 4                      331.0                    1011.0                  151.0
# ...                      ...                       ...                    ...
# 1329                   143.0                     282.0                   83.0
# 1330                    91.0                     387.0                   87.0
# 1331                    91.0                     387.0                   87.0
# 1332                    91.0                     387.0                   87.0
# 1333                   135.0                     242.0                   69.0
#
#       occ_manuf_transpo_wgt  hh_med_income_wgt  hlthins_priv_wgt  \
# 0                     653.0            54480.0            2156.0
# 1                     993.0            44136.0            1885.0
# 2                    1045.0            66970.0            3947.0
# 3                     465.0            54967.0            3794.0
# 4                     134.0           119595.0            4400.0
# ...                     ...                ...               ...
# 1329                   41.0           149332.0            2318.0
# 1330                   46.0           122188.0            2418.0
# 1331                   46.0           122188.0            2418.0
# 1332                   46.0           122188.0            2418.0
# 1333                   23.0           164268.0            2287.0
#
#       hlthins_public_wgt  hlthins_none_wgt
# 0                 2846.0            1050.0
# 1                 3583.0            1700.0
# 2                 2926.0            1356.0
# 3                 2708.0             822.0
# 4                 1523.0             259.0
# ...                  ...               ...
# 1329              1016.0             119.0
# 1330               997.0             125.0
# 1331               997.0             125.0
# 1332               997.0             125.0
# 1333               999.0              71.0
#
# [1334 rows x 19 columns]

# %%
srprec_census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1334 entries, 0 to 1333
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   srprec_orig               1334 non-null   float64
#  1   subindex                  1334 non-null   float64
#  2   pctsrprec_tract           1334 non-null   float64
#  3   employed_wgt              1334 non-null   float64
#  4   unemployed_wgt            1334 non-null   float64
#  5   empl_military_wgt         1334 non-null   float64
#  6   not_inlaborforce_wgt      1334 non-null   float64
#  7   working_women_wgt         1334 non-null   float64
#  8   parents_work_under6_wgt   1334 non-null   float64
#  9   parents_work_0617_wgt     1334 non-null   float64
#  10  occ_mgmt_sci_art_wgt      1334 non-null   float64
#  11  occ_service_sector_wgt    1334 non-null   float64
#  12  occ_sales_gen_office_wgt  1334 non-null   float64
#  13  occ_constr_maintc_wgt     1334 non-null   float64
#  14  occ_manuf_transpo_wgt     1334 non-null   float64
#  15  hh_med_income_wgt         1334 non-null   float64
#  16  hlthins_priv_wgt          1334 non-null   float64
#  17  hlthins_public_wgt        1334 non-null   float64
#  18  hlthins_none_wgt          1334 non-null   float64
# dtypes: float64(19)
# memory usage: 198.1 KB

# %% [markdown]
# #### Step 2:  Merge in Vote data on 'srprec'

# %%
#may need to rename traceability column in advance of second merge
#should be dropped already by .groupby() aggregation step, but a reminder just in case:

# df.rename(columns={'_merge':'census_merge'}, inplace=True)

# %% [markdown]
# #### Vote dataset

# %%
vote18 = pd.read_pickle('./data/trend18.pkl')
vote18.shape
# Out:
# (1334, 26)

# %%
vote18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1334 entries, 0 to 1545
# Data columns (total 26 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   county    1334 non-null   int64
#  1   srprec    1334 non-null   Int64
#  2   cddist    1334 non-null   int64
#  3   TOTREG    1334 non-null   int64
#  4   TOTVOTE   1334 non-null   int64
#  5   CNGDEM01  1334 non-null   int64
#  6   CNGREP01  1334 non-null   int64
#  7   election  1334 non-null   object
#  8   type      1334 non-null   object
#  9   totreg_r  1334 non-null   float64
#  10  dem       1334 non-null   float64
#  11  rep       1334 non-null   float64
#  12  aip       1334 non-null   float64
#  13  paf       1334 non-null   float64
#  14  msc       1334 non-null   float64
#  15  lib       1334 non-null   float64
#  16  nlp       1334 non-null   float64
#  17  grn       1334 non-null   float64
#  18  ref       1334 non-null   float64
#  19  dcl       1334 non-null   float64
#  20  male      1334 non-null   float64
#  21  female    1334 non-null   float64
#  22  hispdem   1334 non-null   float64
#  23  hisprep   1334 non-null   float64
#  24  hispdcl   1334 non-null   float64
#  25  hispoth   1334 non-null   float64
# dtypes: Int64(1), float64(17), int64(6), object(2)
# memory usage: 282.7+ KB

# %%
vote18['srprec'] = vote18['srprec'].astype('int64')

# %%
vote18.head(3)
# Out:
#    county  srprec  cddist  TOTREG  TOTVOTE  CNGDEM01  CNGREP01 election type  \
# 0      30   10316      47    1735     1278       630       592      g18    V
# 1      30   10317      47    2079     1214       638       513      g18    V
# 2      30   10319      47    1448      999       495       462      g18    V
#
#    totreg_r  ...  nlp  grn  ref    dcl   male  female  hispdem  hisprep  \
# 0    1238.0  ...  0.0  2.0  0.0  265.0  582.0   656.0     55.0     43.0
# 1    1184.0  ...  0.0  4.0  0.0  286.0  588.0   596.0    165.0     60.0
# 2     945.0  ...  0.0  2.0  2.0  256.0  443.0   502.0     68.0     37.0
#
#    hispdcl  hispoth
# 0     30.0      6.0
# 1     71.0     10.0
# 2     49.0      5.0
#
# [3 rows x 26 columns]

# %%
# examine the magnitude of the various party-registrations to see which are the largest affiliations
vote18[['totreg_r', 'dem', 'rep', 'dcl', 'aip', 'paf', 'msc', 'lib', 'nlp', 'grn', 'ref']].describe()
# Out:
#           totreg_r          dem          rep          dcl          aip  \
# count  1334.000000  1334.000000  1334.000000  1334.000000  1334.000000
# mean    799.916792   277.739880   306.970765   185.386807    18.483508
# std     541.892084   194.984814   247.478110   130.806513    14.065092
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%     358.000000   119.000000    99.000000    81.250000     7.000000
# 50%     748.000000   261.000000   263.500000   172.000000    17.000000
# 75%    1224.000000   407.000000   464.500000   278.000000    28.000000
# max    3012.000000  1281.000000  1289.000000   828.000000    90.000000
#
#                paf          msc          lib          nlp          grn  \
# count  1334.000000  1334.000000  1334.000000  1334.000000  1334.000000
# mean      1.151424     1.087706     6.274363     0.173163     2.229385
# std       1.405544     1.330224     5.319752     0.455852     2.217337
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     2.000000     0.000000     0.000000
# 50%       1.000000     1.000000     5.000000     0.000000     2.000000
# 75%       2.000000     2.000000    10.000000     0.000000     3.000000
# max       8.000000    10.000000    42.000000     3.000000    14.000000
#
#                ref
# count  1334.000000
# mean      0.419790
# std       0.761468
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       6.000000

# %%
#drop party affiliations that are small.  Keep:  dem, rep, dcl (decline-to-state, i.e., not affiliated)
#drop 'type'.  V indicates all voters (by mail and at polling place).  all columns contain "V", so this column provides no additional information

vote18.drop(columns=['aip', 'paf', 'msc', 'lib', 'nlp', 'grn', 'ref', 'type'], inplace=True)
# Out:
# -----------------------------------------------------------------------
# KeyError                              Traceback (most recent call last)
# <ipython-input-81-5267c8880065> in <module>
#       2 #drop 'type'.  V indicates all voters (by mail and at polling place).  all columns contain "V", so this column provides no additional information
#       3
# ----> 4 vote18.drop(columns=['aip', 'paf', 'msc', 'lib', 'nlp', 'grn', 'ref', 'type'], inplace=True)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['aip' 'paf' 'msc' 'lib' 'nlp' 'grn' 'ref' 'type'] not found in axis"

# %%
vote18.head(3)
# Out:
#    county  srprec  cddist  TOTREG  TOTVOTE  CNGDEM01  CNGREP01 election  \
# 0      30   10316      47    1735     1278       630       592      g18
# 1      30   10317      47    2079     1214       638       513      g18
# 2      30   10319      47    1448      999       495       462      g18
#
#    totreg_r    dem    rep    dcl   male  female  hispdem  hisprep  hispdcl  \
# 0    1238.0  423.0  517.0  265.0  582.0   656.0     55.0     43.0     30.0
# 1    1184.0  490.0  356.0  286.0  588.0   596.0    165.0     60.0     71.0
# 2     945.0  316.0  335.0  256.0  443.0   502.0     68.0     37.0     49.0
#
#    hispoth
# 0      6.0
# 1     10.0
# 2      5.0

# %% [markdown]
# #### Merge vote data into srprec_census df on 'srprec'

# %%
combo2 = pd.merge(left=srprec_census, right=vote18, how='outer', left_on=['srprec_orig'], right_on=['srprec'], indicator=True)
combo2.head().T
# Out:
#                               0      1      2      3       4
# srprec_orig                2001   2002   2008   2009    2011
# subindex                      3      0      0      3       0
# pctsrprec_tract             100    100    100    100     100
# employed_wgt               2647   2881   3948   3045    2991
# unemployed_wgt              161    217    278    147      74
# empl_military_wgt             0      9      0      0       0
# not_inlaborforce_wgt       1372   1525   1438   2459    1401
# working_women_wgt          1152   1030   1656   1447    1486
# parents_work_under6_wgt     268    257    561    273     334
# parents_work_0617_wgt       783   1082    677    717     492
# occ_mgmt_sci_art_wgt        244    363    675    693    1364
# occ_service_sector_wgt      637    573    796    701     331
# occ_sales_gen_office_wgt    706    383   1064    912    1011
# occ_constr_maintc_wgt       405    569    368    274     151
# occ_manuf_transpo_wgt       653    993   1045    465     134
# hh_med_income_wgt         54480  44136  66970  54967  119595
# hlthins_priv_wgt           2156   1885   3947   3794    4400
# hlthins_public_wgt         2846   3583   2926   2708    1523
# hlthins_none_wgt           1050   1700   1356    822     259
# county                       30     30     30     30      30
# srprec                     2001   2002   2008   2009    2011
# cddist                       46     46     46     46      45
# TOTREG                      684    295   2341   1450    1113
# TOTVOTE                     381    123   1295    772     829
# CNGDEM01                    249    100    929    515     368
# CNGREP01                    126     17    295    229     439
# election                    g18    g18    g18    g18     g18
# totreg_r                    371    109   1197    735     805
# dem                         161     61    621    380     251
# rep                         106      8    234    177     360
# dcl                          83     39    301    160     167
# male                        173     46    574    359     415
# female                      198     63    623    376     390
# hispdem                     106     52    376    169      59
# hisprep                      20      0     60     39      29
# hispdcl                      56     23    171     54      30
# hispoth                       7      0     12      1       5
# _merge                     both   both   both   both    both

# %%
combo2.shape
# Out:
# (1334, 38)

# %%
combo2['_merge'].value_counts()
# Out:
# both          1334
# right_only       0
# left_only        0
# Name: _merge, dtype: int64

# %%
combo2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1334 entries, 0 to 1333
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   srprec_orig               1334 non-null   float64
#  1   subindex                  1334 non-null   float64
#  2   pctsrprec_tract           1334 non-null   float64
#  3   employed_wgt              1334 non-null   float64
#  4   unemployed_wgt            1334 non-null   float64
#  5   empl_military_wgt         1334 non-null   float64
#  6   not_inlaborforce_wgt      1334 non-null   float64
#  7   working_women_wgt         1334 non-null   float64
#  8   parents_work_under6_wgt   1334 non-null   float64
#  9   parents_work_0617_wgt     1334 non-null   float64
#  10  occ_mgmt_sci_art_wgt      1334 non-null   float64
#  11  occ_service_sector_wgt    1334 non-null   float64
#  12  occ_sales_gen_office_wgt  1334 non-null   float64
#  13  occ_constr_maintc_wgt     1334 non-null   float64
#  14  occ_manuf_transpo_wgt     1334 non-null   float64
#  15  hh_med_income_wgt         1334 non-null   float64
#  16  hlthins_priv_wgt          1334 non-null   float64
#  17  hlthins_public_wgt        1334 non-null   float64
#  18  hlthins_none_wgt          1334 non-null   float64
#  19  county                    1334 non-null   int64
#  20  srprec                    1334 non-null   int64
#  21  cddist                    1334 non-null   int64
#  22  TOTREG                    1334 non-null   int64
#  23  TOTVOTE                   1334 non-null   int64
#  24  CNGDEM01                  1334 non-null   int64
#  25  CNGREP01                  1334 non-null   int64
#  26  election                  1334 non-null   object
#  27  totreg_r                  1334 non-null   float64
#  28  dem                       1334 non-null   float64
#  29  rep                       1334 non-null   float64
#  30  dcl                       1334 non-null   float64
#  31  male                      1334 non-null   float64
#  32  female                    1334 non-null   float64
#  33  hispdem                   1334 non-null   float64
#  34  hisprep                   1334 non-null   float64
#  35  hispdcl                   1334 non-null   float64
#  36  hispoth                   1334 non-null   float64
#  37  _merge                    1334 non-null   category
# dtypes: category(1), float64(29), int64(7), object(1)
# memory usage: 397.4+ KB

# %%
combo2.to_pickle('./data/combined18_extended.pkl')
