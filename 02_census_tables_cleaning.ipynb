# %%
# imports
import pandas as pd
import requests
import pickle as pkl
key = '18e51257407f16cc376fc7813020069f9f4a323d'

# %% [markdown]
# video:  https://www.youtube.com/watch?v=K0-ifZS0mQI&feature=emb_title&ab_channel=U.S.CensusBureau
#
# https://www.census.gov/data/developers/data-sets/acs-5year.html
#
# Data Profiles
#
# Example Call: api.census.gov/data/2018/acs/acs5/profile?get=group(DP02)&for=us:1&key=YOUR_KEY_GOES_HERE
#
# Desired Call DP03:  https://api.census.gov/data/2018/acs/acs5/profile?get=group(DP03),NAME&for=tract:*&in=state:06&in=county:059
#
# OR
#
# https://api.census.gov/data/2018/acs/acs5/profile?get=group(DP03),NAME&for=tract:*&in=state:06%20county:059
#
# Can't right click to save as CSV
# Above URL

# %% [markdown]
# #### Example API call from Caroline:

# %%
# Set base url
# url = 'https://api.census.gov/data/2018/acs/acs5/profile?'
# # Set params
# params = {
#     'get': 'group(DP05),NAME',
#     'for': 'county:*',
#     'in': 'state:06',
#     'key': key
# }
# # Make a request and display the response code.
# res = requests.get(url,params)
# res

# %%
# data = res.json()
# data

# %% [markdown]
# #### API call adjusted to pull Orange County by census tract

# %%
# Set base url
url = 'https://api.census.gov/data/2018/acs/acs5/profile?'

params2 = {
    'get': 'group(DP03),NAME',
    'for': 'tract:*',
    'in': 'state:06%20county:059',
    'key': key
}
# Make a request and display the response code.
res2 = requests.get(url,params2)
res2
# Out:
# <Response [200]>

# %%
raw = res2.json()
# data2
#returns a veryvery long list

# %%
df_raw = pd.DataFrame(raw)

# %%
df_raw.shape
# Out:
# (584, 1102)

# %%
df_raw.tail()
# Out:
#                                                0                     1     \
# 579  Census Tract 626.48, Orange County, California  1400000US06059062648
# 580  Census Tract 626.49, Orange County, California  1400000US06059062649
# 581  Census Tract 875.05, Orange County, California  1400000US06059087505
# 582    Census Tract 9800, Orange County, California  1400000US06059980000
# 583    Census Tract 9901, Orange County, California  1400000US06059990100
#
#      2    3     4           5     6    7             8             9     ...  \
# 579  2689  162  2689  -888888888   424  110          15.8           3.9  ...
# 580  3012  183  3012  -888888888  1291  173          42.9           5.0  ...
# 581  3718  384  3718  -888888888  2426  250          65.3           5.0  ...
# 582    30   15    30  -888888888    14   13          46.7          39.6  ...
# 583     0   12     0  -888888888     0   12  -666666666.0  -222222222.0  ...
#
#     1092  1093  1094 1095 1096  1097  1098 1099 1100    1101
# 579  (X)  None  None  (X)  (X)  None  None   06  059  062648
# 580  (X)  None  None  (X)  (X)  None  None   06  059  062649
# 581  (X)  None  None  (X)  (X)  None  None   06  059  087505
# 582  (X)     -    **  (X)  (X)     -    **   06  059  980000
# 583  (X)     -    **  (X)  (X)     -    **   06  059  990100
#
# [5 rows x 1102 columns]

# %%
df_raw.to_pickle('./Orange_County_Voting_Trends/census_data/.DP03_raw.pkl')

# %%
# df.to_pickle('my_df.pickle')
# df2 = pd.read_pickle('my_df.pickle')

# df2.to_pickle('./Cap-Census-data/DP02_raw.p')
df_raw.to_pickle('./census-data/DP03_raw.pkl')
# df2.to_pickle('./Cap-Census-data/DP04_raw.p')
# df2.to_pickle('./Cap-Census-data/DP05_raw.p')
# Out:
# -----------------------------------------------------------------------
# FileNotFoundError                     Traceback (most recent call last)
# <ipython-input-14-d27d2c715b2d> in <module>
#       3
#       4 # df2.to_pickle('./Cap-Census-data/DP02_raw.p')
# ----> 5 df_raw.to_pickle('./census-data/DP03_raw.pkl')
#       6 # df2.to_pickle('./Cap-Census-data/DP04_raw.p')
#       7 # df2.to_pickle('./Cap-Census-data/DP05_raw.p')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_pickle(self, path, compression, protocol)
#    2674         from pandas.io.pickle import to_pickle
#    2675
# -> 2676         to_pickle(self, path, compression=compression, protocol=protocol)
#    2677
#    2678     def to_clipboard(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/pickle.py in to_pickle(obj, filepath_or_buffer, compression, protocol)
#      81     if not isinstance(fp_or_buf, str) and compression == "infer":
#      82         compression = None
# ---> 83     f, fh = get_handle(fp_or_buf, "wb", compression=compression, is_text=False)
#      84     if protocol < 0:
#      85         protocol = pickle.HIGHEST_PROTOCOL
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     497         else:
#     498             # Binary mode
# --> 499             f = open(path_or_buf, mode)
#     500         handles.append(f)
#     501
#
# FileNotFoundError: [Errno 2] No such file or directory: './census-data/DP03_raw.pkl'

# %%
pdf = pd.read_pickle('./Cap-Census-data/DP03_raw.p')

# %%
pdf.shape
# Out:
# (584, 1102)

# %%
pdf.head(2)
# Out:
#                                              0                     1     \
# 0                                            NAME                GEO_ID
# 1  Census Tract 626.44, Orange County, California  1400000US06059062644
#
#          2           3            4            5           6           7     \
# 0  DP03_0001E  DP03_0001M  DP03_0001PE  DP03_0001PM  DP03_0002E  DP03_0002M
# 1        6767         423         6767   -888888888        3967         410
#
#           8            9     ...         1092          1093          1094  \
# 0  DP03_0002PE  DP03_0002PM  ...  DP03_0136MA  DP03_0136PEA  DP03_0136PMA
# 1         58.6          5.2  ...          (X)          None          None
#
#           1095         1096          1097          1098   1099    1100    1101
# 0  DP03_0137MA  DP03_0137EA  DP03_0137PEA  DP03_0137PMA  state  county   tract
# 1          (X)          (X)          None          None     06     059  062644
#
# [2 rows x 1102 columns]

# %%
#df.columns = df.iloc[0]

pdf.columns = pdf.iloc[0]

# %%
pdf.head(2)
# Out:
# 0                                            NAME                GEO_ID  \
# 0                                            NAME                GEO_ID
# 1  Census Tract 626.44, Orange County, California  1400000US06059062644
#
# 0  DP03_0001E  DP03_0001M  DP03_0001PE  DP03_0001PM  DP03_0002E  DP03_0002M  \
# 0  DP03_0001E  DP03_0001M  DP03_0001PE  DP03_0001PM  DP03_0002E  DP03_0002M
# 1        6767         423         6767   -888888888        3967         410
#
# 0  DP03_0002PE  DP03_0002PM  ...  DP03_0136MA  DP03_0136PEA  DP03_0136PMA  \
# 0  DP03_0002PE  DP03_0002PM  ...  DP03_0136MA  DP03_0136PEA  DP03_0136PMA
# 1         58.6          5.2  ...          (X)          None          None
#
# 0  DP03_0137MA  DP03_0137EA  DP03_0137PEA  DP03_0137PMA  state  county   tract
# 0  DP03_0137MA  DP03_0137EA  DP03_0137PEA  DP03_0137PMA  state  county   tract
# 1          (X)          (X)          None          None     06     059  062644
#
# [2 rows x 1102 columns]

# %%
#df.drop(['c', 'd'], inplace = True ) 
pdf.drop(0, axis=0, inplace=True)

# %%
pdf.head(2)
# Out:
# 0                                            NAME                GEO_ID  \
# 1  Census Tract 626.44, Orange County, California  1400000US06059062644
# 2  Census Tract 626.40, Orange County, California  1400000US06059062640
#
# 0 DP03_0001E DP03_0001M DP03_0001PE DP03_0001PM DP03_0002E DP03_0002M  \
# 1       6767        423        6767  -888888888       3967        410
# 2       3062        254        3062  -888888888       2446        244
#
# 0 DP03_0002PE DP03_0002PM  ... DP03_0136MA DP03_0136PEA DP03_0136PMA  \
# 1        58.6         5.2  ...         (X)         None         None
# 2        79.9         4.0  ...         (X)         None         None
#
# 0 DP03_0137MA DP03_0137EA DP03_0137PEA DP03_0137PMA state county   tract
# 1         (X)         (X)         None         None    06    059  062644
# 2         (X)         (X)         None         None    06    059  062640
#
# [2 rows x 1102 columns]

# %%
headers = pd.read_csv('./Cap-Census-data/ACSDP5Y2018.DP03_metadata_2020-10-29T195609.csv')
headers.shape
# Out:
# (549, 2)

# %%
1102%549
# Out:
# 4

# %%
headers.head(4)
# Out:
#         GEO_ID                                                 id
# 0         NAME                               Geographic Area Name
# 1   DP03_0001E  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 2   DP03_0001M  Margin of Error!!EMPLOYMENT STATUS!!Population...
# 3  DP03_0001PE  Percent Estimate!!EMPLOYMENT STATUS!!Populatio...

# %%
labels = {}

# %%
key = headers['GEO_ID'].tolist()

# %%
value = headers['id'].tolist()
len(value)
# Out:
# 549

# %%
#dict(zip(header_cols, descriptions))
labels = dict(zip(key, value))

# %%
pdf.rename(columns = labels, inplace=True)

# %%
pdf.head(6)
# Out:
# 0                            Geographic Area Name                GEO_ID  \
# 1  Census Tract 626.44, Orange County, California  1400000US06059062644
# 2  Census Tract 626.40, Orange County, California  1400000US06059062640
# 3  Census Tract 630.08, Orange County, California  1400000US06059063008
# 4  Census Tract 631.03, Orange County, California  1400000US06059063103
# 5  Census Tract 637.01, Orange County, California  1400000US06059063701
# 6  Census Tract 639.03, Orange County, California  1400000US06059063903
#
# 0 Estimate!!EMPLOYMENT STATUS!!Population 16 years and over  \
# 1                                               6767
# 2                                               3062
# 3                                                833
# 4                                               2189
# 5                                               4348
# 6                                               3193
#
# 0 Margin of Error!!EMPLOYMENT STATUS!!Population 16 years and over  \
# 1                                                423
# 2                                                254
# 3                                                 66
# 4                                                208
# 5                                                348
# 6                                                295
#
# 0 Percent Estimate!!EMPLOYMENT STATUS!!Population 16 years and over  \
# 1                                               6767
# 2                                               3062
# 3                                                833
# 4                                               2189
# 5                                               4348
# 6                                               3193
#
# 0 Percent Margin of Error!!EMPLOYMENT STATUS!!Population 16 years and over  \
# 1                                         -888888888
# 2                                         -888888888
# 3                                         -888888888
# 4                                         -888888888
# 5                                         -888888888
# 6                                         -888888888
#
# 0 Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force  \
# 1                                               3967
# 2                                               2446
# 3                                                431
# 4                                               1514
# 5                                               3106
# 6                                               2163
#
# 0 Margin of Error!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force  \
# 1                                                410
# 2                                                244
# 3                                                 63
# 4                                                169
# 5                                                317
# 6                                                284
#
# 0 Percent Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force  \
# 1                                               58.6
# 2                                               79.9
# 3                                               51.7
# 4                                               69.2
# 5                                               71.4
# 6                                               67.7
#
# 0 Percent Margin of Error!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force  \
# 1                                                5.2
# 2                                                4.0
# 3                                                6.7
# 4                                                4.5
# 5                                                5.0
# 6                                                6.7
#
# 0  ... DP03_0136MA DP03_0136PEA DP03_0136PMA DP03_0137MA DP03_0137EA  \
# 1  ...         (X)         None         None         (X)         (X)
# 2  ...         (X)         None         None         (X)         (X)
# 3  ...         (X)         None         None         (X)         (X)
# 4  ...         (X)         None         None         (X)         (X)
# 5  ...         (X)         None         None         (X)         (X)
# 6  ...         (X)         None         None         (X)         (X)
#
# 0 DP03_0137PEA DP03_0137PMA state county   tract
# 1         None         None    06    059  062644
# 2         None         None    06    059  062640
# 3         None         None    06    059  063008
# 4         None         None    06    059  063103
# 5         None         None    06    059  063701
# 6         None         None    06    059  063903
#
# [6 rows x 1102 columns]

# %% [markdown]
# 1. drop "blah" DP03_0136MA
#
# 2. drop extraneous
# 'Margin of Error!!
# 'Percent Margin of Error!!
# 'Percent Estimate!!
#
# 3. edit name of remaining

# %%
blah_cols = pdf.columns[pdf.columns.str.contains('DP03')]
blah_cols
# Out:
# Index(['DP03_0001EA', 'DP03_0001MA', 'DP03_0001PEA', 'DP03_0001PMA',
#        'DP03_0002EA', 'DP03_0002MA', 'DP03_0002PMA', 'DP03_0002PEA',
#        'DP03_0003MA', 'DP03_0003EA',
#        ...
#        'DP03_0135PMA', 'DP03_0135PEA', 'DP03_0136EA', 'DP03_0136MA',
#        'DP03_0136PEA', 'DP03_0136PMA', 'DP03_0137MA', 'DP03_0137EA',
#        'DP03_0137PEA', 'DP03_0137PMA'],
#       dtype='object', name=0, length=548)

# %%
#df = df.drop(['Q43'], axis=1)
pdf = pdf.drop(blah_cols, axis=1)

# %%
pdf.shape
# Out:
# (583, 554)

# %%
moe_cols = pdf.columns[pdf.columns.str.contains('Margin of Error!!')]
# Out:
# Index(['Margin of Error!!EMPLOYMENT STATUS!!Population 16 years and over',
#        'Percent Margin of Error!!EMPLOYMENT STATUS!!Population 16 years and over',
#        'Margin of Error!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force',
#        'Percent Margin of Error!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force',
#        'Margin of Error!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force',
#        'Percent Margin of Error!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force',
#        'Margin of Error!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Employed',
#        'Percent Margin of Error!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Employed',
#        'Margin of Error!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Unemployed',
#        'Percent Margin of Error!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Unemployed',
#        ...
#        'Margin of Error!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All people!!18 years and over',
#        'Percent Margin of Error!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All people!!18 years and over',
#        'Margin of Error!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All people!!18 years and over!!18 to 64 years',
#        'Percent Margin of Error!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All people!!18 years and over!!18 to 64 years',
#        'Margin of Error!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All people!!18 years and over!!65 years and over',
#        'Percent Margin of Error!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All people!!18 years and over!!65 years and over',
#        'Margin of Error!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!People in families',
#        'Percent Margin of Error!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!People in families',
#        'Margin of Error!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!Unrelated individuals 15 years and over',
#        'Percent Margin of Error!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!Unrelated individuals 15 years and over'],
#       dtype='object', name=0, length=274)

# %%
pdf = pdf.drop(moe_cols, axis=1)

# %%
pdf.shape
# Out:
# (583, 280)

# %%
pct_cols = pdf.columns[pdf.columns.str.contains('Percent Estimate!!')]

# %%
pdf = pdf.drop(pct_cols, axis=1)

# %%
pdf.shape
# Out:
# (583, 143)

# %%
pdf.head(2)
# Out:
# 0                            Geographic Area Name                GEO_ID  \
# 1  Census Tract 626.44, Orange County, California  1400000US06059062644
# 2  Census Tract 626.40, Orange County, California  1400000US06059062640
#
# 0 Estimate!!EMPLOYMENT STATUS!!Population 16 years and over  \
# 1                                               6767
# 2                                               3062
#
# 0 Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force  \
# 1                                               3967
# 2                                               2446
#
# 0 Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force  \
# 1                                               3967
# 2                                               2436
#
# 0 Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Employed  \
# 1                                               3811
# 2                                               2320
#
# 0 Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Unemployed  \
# 1                                                156
# 2                                                116
#
# 0 Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Armed Forces  \
# 1                                                  0
# 2                                                 10
#
# 0 Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!Not in labor force  \
# 1                                               2800
# 2                                                616
#
# 0 Estimate!!EMPLOYMENT STATUS!!Civilian labor force  ...  \
# 1                                              3967  ...
# 2                                              2436  ...
#
# 0 Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All people!!Under 18 years!!Related children of the householder under 18 years!!Related children of the householder 5 to 17 years  \
# 1                                       -888888888.0
# 2                                       -888888888.0
#
# 0 Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All people!!18 years and over  \
# 1                                       -888888888.0
# 2                                       -888888888.0
#
# 0 Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All people!!18 years and over!!18 to 64 years  \
# 1                                       -888888888.0
# 2                                       -888888888.0
#
# 0 Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All people!!18 years and over!!65 years and over  \
# 1                                       -888888888.0
# 2                                       -888888888.0
#
# 0 Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!People in families  \
# 1                                       -888888888.0
# 2                                       -888888888.0
#
# 0 Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!Unrelated individuals 15 years and over  \
# 1                                       -888888888.0
# 2                                       -888888888.0
#
# 0                            Geographic Area Name state county   tract
# 1  Census Tract 626.44, Orange County, California    06    059  062644
# 2  Census Tract 626.40, Orange County, California    06    059  062640
#
# [2 rows x 143 columns]

# %%
pdf.columns = pdf.columns.str.replace('!!', " ")

# %%
pdf.head(2)
# Out:
# 0                            Geographic Area Name                GEO_ID  \
# 1  Census Tract 626.44, Orange County, California  1400000US06059062644
# 2  Census Tract 626.40, Orange County, California  1400000US06059062640
#
# 0 Estimate EMPLOYMENT STATUS Population 16 years and over  \
# 1                                               6767
# 2                                               3062
#
# 0 Estimate EMPLOYMENT STATUS Population 16 years and over In labor force  \
# 1                                               3967
# 2                                               2446
#
# 0 Estimate EMPLOYMENT STATUS Population 16 years and over In labor force Civilian labor force  \
# 1                                               3967
# 2                                               2436
#
# 0 Estimate EMPLOYMENT STATUS Population 16 years and over In labor force Civilian labor force Employed  \
# 1                                               3811
# 2                                               2320
#
# 0 Estimate EMPLOYMENT STATUS Population 16 years and over In labor force Civilian labor force Unemployed  \
# 1                                                156
# 2                                                116
#
# 0 Estimate EMPLOYMENT STATUS Population 16 years and over In labor force Armed Forces  \
# 1                                                  0
# 2                                                 10
#
# 0 Estimate EMPLOYMENT STATUS Population 16 years and over Not in labor force  \
# 1                                               2800
# 2                                                616
#
# 0 Estimate EMPLOYMENT STATUS Civilian labor force  ...  \
# 1                                            3967  ...
# 2                                            2436  ...
#
# 0 Estimate PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL All people Under 18 years Related children of the householder under 18 years Related children of the householder 5 to 17 years  \
# 1                                       -888888888.0
# 2                                       -888888888.0
#
# 0 Estimate PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL All people 18 years and over  \
# 1                                       -888888888.0
# 2                                       -888888888.0
#
# 0 Estimate PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL All people 18 years and over 18 to 64 years  \
# 1                                       -888888888.0
# 2                                       -888888888.0
#
# 0 Estimate PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL All people 18 years and over 65 years and over  \
# 1                                       -888888888.0
# 2                                       -888888888.0
#
# 0 Estimate PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL People in families  \
# 1                                       -888888888.0
# 2                                       -888888888.0
#
# 0 Estimate PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL Unrelated individuals 15 years and over  \
# 1                                       -888888888.0
# 2                                       -888888888.0
#
# 0                            Geographic Area Name state county   tract
# 1  Census Tract 626.44, Orange County, California    06    059  062644
# 2  Census Tract 626.40, Orange County, California    06    059  062640
#
# [2 rows x 143 columns]

# %%
# pdf.to_pickle('my_df.pickle')

# pdf.to_pickle('./Cap-Census-data/DP02_raw.p')
pdf.to_pickle('./Cap-Census-data/DP03_clean.p')
# pdf.to_pickle('./Cap-Census-data/DP04_raw.p')
# pdf.to_pickle('./Cap-Census-data/DP05_raw.p')

# %%
# Extract the header columns as a list.
header_cols = list(header_df.columns)

# Drop the second row of the dataframe.
row_one_df = header_df.iloc[:1, :]

# Display the dataframe.
row_one_df

# Convert the row of the dataframe into a list
descriptions = row_one_df.values.tolist()

# The output is a nested list. Extract the list.
descriptions = descriptions[0]

# View the first five entries
descriptions[:5]

# Create a dictionary from a zipped list of the header columns and descriptions.
header_dict = dict(zip(header_cols, descriptions))

# View the first five entries in the dictionary
list(header_dict.items())[:5]

# Rename the colums in the original dataframe according to the dictionary
df.rename(columns = header_dict, inplace=True)
